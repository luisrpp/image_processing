# %% [markdown]
# # Image Processing in Ruby
#
# ## Hough Transform
#
# In this notebook, we will use the Hough Transform to detect lines in images.
#
# The algorithm was implemented in Ruby and is part of the [image_processing](https://github.com/luisrpp/image_processing) gem.

# %% [markdown]
# ### Importing the gem and defining the display method
#
# The first step is to import the *image_processing* gem.

# %%
require 'image_processing'
# Out:
# true

# %% [markdown]
# ### Loading the image

# %%
image = Vips::Image.new_from_file('../../samples/lane.jpg')
image.display
# Out:
# /tmp/vips_image_1506269984.jpg=> JPEG 600x402 600x402+0+0 DirectClass 8-bit 30kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">

# %% [markdown]
# ### Image pre-processing

# %% [markdown]
# Converting the image to greyscale:

# %%
grey = image.to_greyscale
grey.display
# Out:
# /tmp/vips_image_1506269984.jpg=> JPEG 600x402 600x402+0+0 PseudoClass 256c 8-bit 27kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">

# %% [markdown]
# Applying the morphological gradient to make the boundaries more evident:

# %%
gradient = ImageProcessing::Morphology.gradient(grey)
gradient.display
# Out:
# /tmp/vips_image_1506269984.jpg=> JPEG 600x402 600x402+0+0 PseudoClass 256c 8-bit 23kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">

# %% [markdown]
# The morphological gradient on greyscale images usually are sensible to noise. Let's filter the image by applying a threshold:

# %%
filtered_gradient = gradient.threshold(gradient.max / 2)
filtered_gradient.display
# Out:
# /tmp/vips_image_1506269984.jpg=> JPEG 600x402 600x402+0+0 PseudoClass 256c 8-bit 10kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">

# %% [markdown]
# ### Detecting lines

# %%
hough_transform = ImageProcessing::HoughTransform.new(filtered_gradient)

lines = hough_transform.find_lines(theta_res: Math::PI / 540, rho_res: 0.25, threshold: 60)

lines.each { |line| IRuby.display(line) }; puts ''
# Out:
# {:rho=>13.0, :theta=>-0.45378560551852565, :intersections=>840}
# {:rho=>17.0, :theta=>-0.4479678413452113, :intersections=>734}
# {:rho=>5.0, :theta=>-0.47123889803846897, :intersections=>705}
# {:rho=>25.0, :theta=>-0.43051454882526796, :intersections=>697}
# {:rho=>21.0, :theta=>-0.43633231299858233, :intersections=>693}
# {:rho=>9.0, :theta=>-0.45960336969184, :intersections=>687}
# {:rho=>1.0, :theta=>-0.47705666221178333, :intersections=>612}
# {:rho=>17.0, :theta=>-0.4421500771718967, :intersections=>605}
# {:rho=>9.0, :theta=>-0.4654211338651546, :intersections=>595}
# {:rho=>29.0, :theta=>-0.4246967846519536, :intersections=>582}
# {:rho=>277.0, :theta=>0.4654211338651546, :intersections=>576}
# {:rho=>277.0, :theta=>0.45960336969184024, :intersections=>570}
# {:rho=>277.0, :theta=>0.45378560551852587, :intersections=>569}
# {:rho=>277.0, :theta=>0.47123889803846897, :intersections=>527}
# {:rho=>277.0, :theta=>0.4479678413452115, :intersections=>519}

# %%
hough_transform.accumulator_image.display
# Out:
# /tmp/vips_image_1506269986.jpg=> JPEG 540x362 540x362+0+0 PseudoClass 256c 8-bit 3kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">

# %%
result = image.draw_lines([0.0, 0.0, 255.0], lines)
result.display
# Out:
# /tmp/vips_image_1506269986.jpg=> JPEG 600x402 600x402+0+0 DirectClass 8-bit 37kb
# #<CZTop::Socket::PUB:0x56069cb867b0 last_endpoint="tcp://127.0.0.1:41795">
